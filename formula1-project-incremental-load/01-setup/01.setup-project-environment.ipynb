-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_course_ext_dl1_formula1_incr
URL 'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-course-sc`)
COMMENT 'Default source for Azure exernal data';

-- %%
%fs ls 'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/'

-- %%
%fs ls 'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/'

-- %%
SHOW CATALOGS

-- %%
CREATE CATALOG IF NOT EXISTS formula1_incr
  MANAGED LOCATION 'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/'
  COMMENT "main catalog";

-- %%
SHOW CATALOGS

-- %%
CREATE SCHEMA IF NOT EXISTS formula1_incr.landing;
CREATE SCHEMA IF NOT EXISTS formula1_incr.gold
    MANAGED LOCATION'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/gold';
CREATE SCHEMA IF NOT EXISTS formula1_incr.silver
    MANAGED LOCATION'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/silver';
CREATE SCHEMA IF NOT EXISTS formula1_incr.bronze
    MANAGED LOCATION'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/bronze';

-- %%
select current_catalog()

-- %%
use catalog formula1_incr

-- %%
show schemas

-- %%
CREATE EXTERNAL VOLUME IF NOT EXISTS formula1_incr.landing.files
LOCATION 'abfss://formula1-incr@databrickscourseextdl112.dfs.core.windows.net/landing';

-- %%
%fs ls /Volumes/formula1_incr/landing/files
