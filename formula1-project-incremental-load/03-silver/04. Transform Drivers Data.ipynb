# %%
dbutils.widgets.text("p_batch_id", "")
v_batch_id=dbutils.widgets.get("p_batch_id")

# %%
# %run ../00-common/01.enviroment-config

# %%
# %run ../00-common/03.silver_helpers

# %%
bronze_table=f"{catalog_name}.{bronze_schema}.drivers"
silver_table=f"{catalog_name}.{silver_schema}.drivers"

# %%
from pyspark.sql import functions as F

# %%
drivers_df=(spark.table(bronze_table)).filter(F.col("batch_id")==v_batch_id)

# %%
drivers_dropped_df=drivers_df.drop('url')

# %%
drivers_renamed_df=(
    drivers_dropped_df
    .withColumnsRenamed({"driverId": "driver_id",
                        "dateOfBirth":"date_of_birth"
                        })
)

# %%
drivers_concatenated_df=(
    drivers_renamed_df.withColumn("driver_name",F.initcap(F.concat_ws(" ", F.col("name.givenName"), F.col("name.familyName")))) 
    .drop("name")

)

# %%
drivers_distinct_df=drivers_concatenated_df.dropDuplicates(["driver_id"])

# %%
drivers_final_df=(drivers_distinct_df
    .withColumn('nationality',F.initcap(F.col("nationality"))))

# %%
write_to_silver(
    input_df=drivers_final_df,
    target_table=silver_table,
    merge_condition="t.driverId = s.driverId",
    columns_to_update=["driver_id", "driver_name", "date_of_birth", "nationality", "ingestion_timestamp", "source_file", "batch_id"] 
)

# %%
# (
#     drivers_final_df
#     .write
#     .format("delta")
#     .mode("overwrite")
#     .saveAsTable(silver_table)
# )

# %%
display(spark.table(silver_table))
